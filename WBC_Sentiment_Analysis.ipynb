# %%
# %%HTML
# Dependencies
#  <ul>
#          <li>pandas</li>
#          <li>tweepy</li>
#          <li>vaderSentiment</li>
#          <li>nltk</li>
#       </ul>
# # !python3 -m pip install pandas
# Out:
# Dependecies
#  <ul>
#          <li>pandas</li>
#          <li>tweepy</li>
#          <li>vaderSentiment</li>
#          <li>nltk</li>
#       </ul>
# # !python3 -m pip install pandas

# %%
import tweepy
import pandas as pd
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
#Twitter API Authentication Variables
consumer_key = 'blah_blah_blah_blah_blah_blah_blah_blah_blah'
consumer_secret = 'blah_blah_blah_blah_blah_blah_blah_blah_blah'
access_token = 'blah_blah_blah_blah_blah_blah_blah_blah_blah'
access_token_secret = 'blah_blah_blah_blah_blah_blah_blah_blah_blah'

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

tweets = api.search('white blood cells', count=200)


data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

display(data.head(10))


print(tweets[0].created_at)
# Out:
#                                               Tweets
# 0  RT @nadashahin94: عندي ولد فالكلاس (أولى ابتدا...
# 1  A report of adverse effects of cladribine for ...
# 2  RT @oswaldtheson: White blood cells are just c...
# 3               Can my white blood cells please work
# 4  RT @nadashahin94: عندي ولد فالكلاس (أولى ابتدا...
# 5  feeling ko nagwawala white blood cells ko tas ...
# 6  Is that a red blood cell?\nBetter send the whi...
# 7  @AuthorViviana Interesting. You could probably...
# 8  RT @nadashahin94: عندي ولد فالكلاس (أولى ابتدا...
# 9  RT @robin_jbrooks: All mammals share the same ...
# 2019-05-07 18:44:38

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/prateek/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
sid = SentimentIntensityAnalyzer()


listy = []

for index, row in data.iterrows():
  ss = sid.polarity_scores(row["Tweets"])
  listy.append(ss)
  
se = pd.Series(listy)
data['polarity'] = se.values

display(data.head(100))
# Out:
#                                                Tweets  \
# 0   RT @nadashahin94: عندي ولد فالكلاس (أولى ابتدا...
# 1   A report of adverse effects of cladribine for ...
# 2   RT @oswaldtheson: White blood cells are just c...
# 3                Can my white blood cells please work
# 4   RT @nadashahin94: عندي ولد فالكلاس (أولى ابتدا...
# 5   feeling ko nagwawala white blood cells ko tas ...
# 6   Is that a red blood cell?\nBetter send the whi...
# 7   @AuthorViviana Interesting. You could probably...
# 8   RT @nadashahin94: عندي ولد فالكلاس (أولى ابتدا...
# 9   RT @robin_jbrooks: All mammals share the same ...
# 10  RT @nadashahin94: عندي ولد فالكلاس (أولى ابتدا...
# 11  White blood cells are hard wired to attack... ...
# 12  these 2 tweets were in my draft and wow,, you ...
# 13  RT @nadashahin94: عندي ولد فالكلاس (أولى ابتدا...
# 14  @KirstieMAllsopp Only when my child was imuno ...
# 15  RT @nadashahin94: عندي ولد فالكلاس (أولى ابتدا...
# ...
